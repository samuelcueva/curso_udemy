# %% [markdown]
# <a href="https://colab.research.google.com/github/joanby/tensorflow2/blob/master/Collab%2013%20-%20Preparar%20un%20modelo%20de%20TensorFlow%20para%20móviles%20con%20TensorFlow%20Lite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Paso 1: Instalar las dependencias y configurar el entorno de trabajo

# %% [markdown]
# ## Paso 2: Importar las dependencias

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras.datasets import fashion_mnist

tf.__version__
# Out:
# '2.4.0'

# %% [markdown]
# ## Paso 3: Pre procesado de datos

# %% [markdown]
# ### Cargar el dataset de FashionMNIST

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ### Normalizar las imágenes

# %%
X_train = X_train / 255.
X_test = X_test / 255.

# %% [markdown]
# ### Redimensionar las imágenes

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)

# %%
X_train.shape
# Out:
# (60000, 784)

# %% [markdown]
# ## Paso 4: Construir el modelo

# %% [markdown]
# ### Definir el modelo

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784,)))
model.add(tf.keras.layers.Dropout(rate=0.2))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %% [markdown]
# ### Compilar el modelo

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

# %% [markdown]
# ### Entrenar el modelo

# %%
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6752 - sparse_categorical_accuracy: 0.7652
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4085 - sparse_categorical_accuracy: 0.8514
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3654 - sparse_categorical_accuracy: 0.8650
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3520 - sparse_categorical_accuracy: 0.8714
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3239 - sparse_categorical_accuracy: 0.8810

# %% [markdown]
# ### Evaluar el modelo

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Precisión del conjunto de test: {}".format(test_accuracy))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3468 - sparse_categorical_accuracy: 0.8765
# Precisión del conjunto de test: 0.8765000104904175

# %% [markdown]
# ## Paso 5: Convertir el modelo a la versión de TensorFlow Lite

# %% [markdown]
# ### Guardar el modelo

# %%
# para tensorflow 2 no se necesita si usas 
model_name = 'fashion_mobile_model.h5'
tf.keras.models.save_model(model, model_name)

# %% [markdown]
# ### Crear el TFLite Converter

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# %% [markdown]
# ### Convertir el modelo

# %%
converter

# %%
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpdwpxyc3_/assets

# %% [markdown]
# ### Guardar la versión de TFLite version del modelo

# %%
with open("tf_model.tflite", "wb") as f:
  f.write(tflite_model)
